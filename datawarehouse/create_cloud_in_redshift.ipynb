# %% [markdown]
# # Creating Redshift Cluster using the AWS python SDK

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# # STEP 0: Make sure you have an AWS secret and access key
#
# - Create a new IAM user in your AWS account
# - Give it `AdministratorAccess`, From `Attach existing policies directly` Tab
# - Take note of the access key and secret
# - Edit the file `aws.cfg` in the same folder as this notebook and fill
# <font color='red'>
# <BR>
# [AWS]<BR>
# KEY= YOUR_AWS_KEY<BR>
# SECRET= YOUR_AWS_SECRET<BR>
# <font/>

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('aws.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           4
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB      public
# 5             DWH_DB_USER    admindwh
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# ## Create clients for EC2, S3, IAM, and Redshift

# %%
import boto3

ec2 = boto3.resource('ec2',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                    )

iam = boto3.client('iam',aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET,
                     region_name='us-west-2'
                  )


redshift = boto3.client('redshift',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                       )

# %% [markdown]
# ## STEP 1: IAM ROLE
# - Create an IAM Role that makes Redshift able to access S3 bucket (ReadOnly)

# %%
from botocore.exceptions import ClientError

#1.1 Create the role, 
try:
    print("1.1 Creating a new IAM Role") 
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    
except Exception as e:
    print(e)
# Out:
# 1.1 Creating a new IAM Role

# %%
print("1.2 Attaching Policy")

iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']
# Out:
# 1.2 Attaching Policy
# 200

# %%
print("1.3 Get the IAM role ARN")
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

print(roleArn)
# Out:
# 1.3 Get the IAM role ARN
# arn:aws:iam::167023846835:role/dwhRole

# %% [markdown]
# ## STEP 2:  Redshift Cluster
#
# - Create a RedShift Cluster
# - For complete arguments to `create_cluster`, see [docs](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster)

# %%
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn]  
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## 2.1 *Describe* the cluster to see its status
# - run this block several times until the cluster status becomes `Available`

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', 1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  available
# 3  admindwh
# 4  public
# 5  {'Address': 'dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0a41629468dbdb865
# 7  4

# %% [markdown]
# <h2> 2.2 Take note of the cluster <font color='red'> endpoint and role ARN </font> </h2>

# %% [markdown]
# <font color='red'>DO NOT RUN THIS unless the cluster status becomes "Available" </font>

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::167023846835:role/dwhRole

# %% [markdown]
# ## STEP 3: Open an incoming  TCP port to access the cluster ednpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-08e2f1e0a2c5adbd5')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %% [markdown]
# ## STEP 4: Make sure you can connect to the clusterConnect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://admindwh:Passw0rd@dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com:5439/public

# %%
# %%sql
# SELECT distinct schemaname, tablename
# FROM PG_TABLE_DEF;
# Out:
#  * postgresql://admindwh:***@dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com:5439/public
# 1691 rows affected.
# [('pg_catalog', 'padb_config_harvest'),
#  ('pg_catalog', 'pg_aggregate'),
#  ('pg_catalog', 'pg_am'),
#  ('pg_catalog', 'pg_amop'),
#  ('pg_catalog', 'pg_amproc'),
#  ('pg_catalog', 'pg_attrdef'),
#  ('pg_catalog', 'pg_attrdef_journal'),
#  ('pg_catalog', 'pg_attribute'),
#  ('pg_catalog', 'pg_attribute_acl'),
#  ('pg_catalog', 'pg_attribute_info'),
#  ('pg_catalog', 'pg_attribute_journal'),
#  ('pg_catalog', 'pg_bar_ddllog'),
#  ('pg_catalog', 'pg_bar_repos'),
#  ('pg_catalog', 'pg_bar_state'),
#  ('pg_catalog', 'pg_cast'),
#  ('pg_catalog', 'pg_catalog_rebuilds'),
#  ('pg_catalog', 'pg_class'),
#  ('pg_catalog', 'pg_class_extended'),
#  ('pg_catalog', 'pg_class_extended_journal'),
#  ('pg_catalog', 'pg_class_info'),
#  ('pg_catalog', 'pg_class_journal'),
#  ('pg_catalog', 'pg_class_stage'),
#  ('pg_catalog', 'pg_conf'),
#  ('pg_catalog', 'pg_constraint'),
#  ('pg_catalog', 'pg_constraint_journal'),
#  ('pg_catalog', 'pg_conversion'),
#  ('pg_catalog', 'pg_database'),
#  ('pg_catalog', 'pg_database_extended'),
#  ('pg_catalog', 'pg_database_info'),
#  ('pg_catalog', 'pg_datashare'),
#  ('pg_catalog', 'pg_datashare_consumers'),
#  ('pg_catalog', 'pg_datashare_objects'),
#  ('pg_catalog', 'pg_default_acl'),
#  ('pg_catalog', 'pg_default_permission'),
#  ('pg_catalog', 'pg_depend'),
#  ('pg_catalog', 'pg_depend_journal'),
#  ('pg_catalog', 'pg_description'),
#  ('pg_catalog', 'pg_external_database'),
#  ('pg_catalog', 'pg_external_schema'),
#  ('pg_catalog', 'pg_group'),
#  ('pg_catalog', 'pg_group_extended'),
#  ('pg_catalog', 'pg_highwatermark'),
#  ('pg_catalog', 'pg_iam_permission'),
#  ('pg_catalog', 'pg_identity'),
#  ('pg_catalog', 'pg_identity_provider'),
#  ('pg_catalog', 'pg_index'),
#  ('pg_catalog', 'pg_indexes'),
#  ('pg_catalog', 'pg_inherits'),
#  ('pg_catalog', 'pg_language'),
#  ('pg_catalog', 'pg_largeobject'),
#  ('pg_catalog', 'pg_library'),
#  ('pg_catalog', 'pg_listener'),
#  ('pg_catalog', 'pg_locks'),
#  ('pg_catalog', 'pg_ml_model'),
#  ('pg_catalog', 'pg_namespace'),
#  ('pg_catalog', 'pg_namespace_extended'),
#  ('pg_catalog', 'pg_opclass'),
#  ('pg_catalog', 'pg_operator'),
#  ('pg_catalog', 'pg_permission'),
#  ('pg_catalog', 'pg_permission_policy'),
#  ('pg_catalog', 'pg_permission_roles'),
#  ('pg_catalog', 'pg_permission_users'),
#  ('pg_catalog', 'pg_policy'),
#  ('pg_catalog', 'pg_policy_impl'),
#  ('pg_catalog', 'pg_proc'),
#  ('pg_catalog', 'pg_proc_extended'),
#  ('pg_catalog', 'pg_proc_info'),
#  ('pg_catalog', 'pg_resize'),
#  ('pg_catalog', 'pg_rewrite'),
#  ('pg_catalog', 'pg_role'),
#  ('pg_catalog', 'pg_role_chain'),
#  ('pg_catalog', 'pg_role_permission'),
#  ('pg_catalog', 'pg_role_users'),
#  ('pg_catalog', 'pg_rules'),
#  ('pg_catalog', 'pg_settings'),
#  ('pg_catalog', 'pg_shadow'),
#  ('pg_catalog', 'pg_shadow_extended'),
#  ('pg_catalog', 'pg_shdepend'),
#  ('pg_catalog', 'pg_stat_activity'),
#  ('pg_catalog', 'pg_stat_all_indexes'),
#  ('pg_catalog', 'pg_stat_all_tables'),
#  ('pg_catalog', 'pg_stat_database'),
#  ('pg_catalog', 'pg_stat_sys_indexes'),
#  ('pg_catalog', 'pg_stat_sys_tables'),
#  ('pg_catalog', 'pg_stat_user_indexes'),
#  ('pg_catalog', 'pg_stat_user_tables'),
#  ('pg_catalog', 'pg_statio_all_indexes'),
#  ('pg_catalog', 'pg_statio_all_sequences'),
#  ('pg_catalog', 'pg_statio_all_tables'),
#  ('pg_catalog', 'pg_statio_sys_indexes'),
#  ('pg_catalog', 'pg_statio_sys_sequences'),
#  ('pg_catalog', 'pg_statio_sys_tables'),
#  ('pg_catalog', 'pg_statio_user_indexes'),
#  ('pg_catalog', 'pg_statio_user_sequences'),
#  ('pg_catalog', 'pg_statio_user_tables'),
#  ('pg_catalog', 'pg_statistic'),
#  ('pg_catalog', 'pg_statistic_indicator'),
#  ('pg_catalog', 'pg_statistic_journal'),
#  ('pg_catalog', 'pg_statistic_multicol'),
#  ('pg_catalog', 'pg_stats'),
#  ('pg_catalog', 'pg_table_def'),
#  ('pg_catalog', 'pg_tables'),
#  ('pg_catalog', 'pg_tablespace'),
#  ('pg_catalog', 'pg_test'),
#  ('pg_catalog', 'pg_transaction'),
#  ('pg_catalog', 'pg_trigger'),
#  ('pg_catalog', 'pg_type'),
#  ('pg_catalog', 'pg_udf'),
#  ('pg_catalog', 'pg_unique_identity'),
#  ('pg_catalog', 'pg_user'),
#  ('pg_catalog', 'pg_user_info'),
#  ('pg_catalog', 'pg_user_permission'),
#  ('pg_catalog', 'pg_user_roles'),
#  ('pg_catalog', 'pg_views'),
#  ('pg_catalog', 'stcs_abort_idle'),
#  ('pg_catalog', 'stcs_aggr'),
#  ('pg_catalog', 'stcs_aggr_distinct'),
#  ('pg_catalog', 'stcs_alert_event_log'),
#  ('pg_catalog', 'stcs_alert_messages'),
#  ('pg_catalog', 'stcs_alter_column_encode_events'),
#  ('pg_catalog', 'stcs_alter_column_events'),
#  ('pg_catalog', 'stcs_alter_dist_sort'),
#  ('pg_catalog', 'stcs_alter_sortkey_events'),
#  ('pg_catalog', 'stcs_analyze'),
#  ('pg_catalog', 'stcs_analyze_compression'),
#  ('pg_catalog', 'stcs_aqua_pushdown'),
#  ('pg_catalog', 'stcs_aqua_requests'),
#  ('pg_catalog', 'stcs_arcadia_billing_log'),
#  ('pg_catalog', 'stcs_arcadia_billing_ris_reports'),
#  ('pg_catalog', 'stcs_arcadia_billing_xact_log'),
#  ('pg_catalog', 'stcs_arcadia_concurrency_scaling_usage'),
#  ('pg_catalog', 'stcs_arcadia_concurrency_scaling_usage_error'),
#  ('pg_catalog', 'stcs_arcadia_main_usage'),
#  ('pg_catalog', 'stcs_arcadia_main_usage_error'),
#  ('pg_catalog', 'stcs_auto_alter_worker_event'),
#  ('pg_catalog', 'stcs_auto_dispatcher_wlm_occupancy'),
#  ('pg_catalog', 'stcs_auto_maintenance'),
#  ('pg_catalog', 'stcs_auto_maintenance_worker'),
#  ('pg_catalog', 'stcs_auto_task_events'),
#  ('pg_catalog', 'stcs_auto_worker_levels'),
#  ('pg_catalog', 'stcs_autovacuum_detail'),
#  ('pg_catalog', 'stcs_autovacuum_skip_reason'),
#  ('pg_catalog', 'stcs_awsclient_error'),
#  ('pg_catalog', 'stcs_background_monitor'),
#  ('pg_catalog', 'stcs_background_tasks'),
#  ('pg_catalog', 'stcs_backtrace'),
#  ('pg_catalog', 'stcs_backup_compute'),
#  ('pg_catalog', 'stcs_backup_leader'),
#  ('pg_catalog', 'stcs_bcast'),
#  ('pg_catalog', 'stcs_bkg_compile_info'),
#  ('pg_catalog', 'stcs_blf_efficiency'),
#  ('pg_catalog', 'stcs_block_access_errors'),
#  ('pg_catalog', 'stcs_block_integrity_error'),
#  ('pg_catalog', 'stcs_block_io_metrics'),
#  ('pg_catalog', 'stcs_block_needs_recovery'),
#  ('pg_catalog', 'stcs_block_pins'),
#  ('pg_catalog', 'stcs_block_priority_based_rereplication'),
#  ('pg_catalog', 'stcs_blocklist'),
#  ('pg_catalog', 'stcs_bootstrap'),
#  ('pg_catalog', 'stcs_burst_async_mark'),
#  ('pg_catalog', 'stcs_burst_connection'),
#  ('pg_catalog', 'stcs_burst_manager_personalization'),
#  ('pg_catalog', 'stcs_burst_manager_refresh'),
#  ('pg_catalog', 'stcs_burst_prepare'),
#  ('pg_catalog', 'stcs_burst_query_execution'),
#  ('pg_catalog', 'stcs_burst_refresh'),
#  ('pg_catalog', 'stcs_burst_service_client'),
#  ('pg_catalog', 'stcs_burst_write_block_header_trace'),
#  ('pg_catalog', 'stcs_burst_write_exec'),
#  ('pg_catalog', 'stcs_burst_write_query_event'),
#  ('pg_catalog', 'stcs_cache_policy_stats'),
#  ('pg_catalog', 'stcs_catalog_bloat'),
#  ('pg_catalog', 'stcs_catalog_bufmgr_stats'),
#  ('pg_catalog', 'stcs_catalog_rebuild_info'),
#  ('pg_catalog', 'stcs_catalog_rebuild_worker'),
#  ('pg_catalog', 'stcs_catalog_scan_metrics'),
#  ('pg_catalog', 'stcs_clear_reps'),
#  ('pg_catalog', 'stcs_client_write_timings'),
#  ('pg_catalog', 'stcs_cluster_blocks_stats'),
#  ('pg_catalog', 'stcs_cmd_requires_top_xact'),
#  ('pg_catalog', 'stcs_codegen'),
#  ('pg_catalog', 'stcs_column_access_metrics'),
#  ('pg_catalog', 'stcs_column_errors'),
#  ('pg_catalog', 'stcs_column_stats'),
#  ('pg_catalog', 'stcs_comm_capture'),
#  ('pg_catalog', 'stcs_comm_diag'),
#  ('pg_catalog', 'stcs_comm_diag_errors'),
#  ('pg_catalog', 'stcs_comm_excess'),
#  ('pg_catalog', 'stcs_comm_integrity_error'),
#  ('pg_catalog', 'stcs_comm_pkt_latency'),
#  ('pg_catalog', 'stcs_comm_pkt_oob_count'),
#  ('pg_catalog', 'stcs_comm_pkt_sent_count'),
#  ('pg_catalog', 'stcs_comm_rexmit'),
#  ('pg_catalog', 'stcs_comm_rexmit_histogram'),
#  ('pg_catalog', 'stcs_command_result'),
#  ('pg_catalog', 'stcs_command_start'),
#  ('pg_catalog', 'stcs_commit_checkpoint'),
#  ('pg_catalog', 'stcs_commit_internal_stats'),
#  ('pg_catalog', 'stcs_commit_regions'),
#  ('pg_catalog', 'stcs_commit_stats'),
#  ('pg_catalog', 'stcs_committed_txn'),
#  ('pg_catalog', 'stcs_compile_info'),
#  ('pg_catalog', 'stcs_compile_print'),
#  ('pg_catalog', 'stcs_compile_service'),
#  ('pg_catalog', 'stcs_complyze'),
#  ('pg_catalog', 'stcs_concurrency_scaling_query_mapping'),
#  ('pg_catalog', 'stcs_concurrency_scaling_usage'),
#  ('pg_catalog', 'stcs_concurrency_scaling_usage_error'),
#  ('pg_catalog', 'stcs_config'),
#  ('pg_catalog', 'stcs_config_chooser'),
#  ('pg_catalog', 'stcs_config_history'),
#  ('pg_catalog', 'stcs_connection_log'),
#  ('pg_catalog', 'stcs_consistency'),
#  ('pg_catalog', 'stcs_core_stat'),
#  ('pg_catalog', 'stcs_cost_control_updates'),
#  ('pg_catalog', 'stcs_cqilog'),
#  ('pg_catalog', 'stcs_create_replication'),
#  ('pg_catalog', 'stcs_dag_cleanup'),
#  ('pg_catalog', 'stcs_datashare_changes_consumer'),
#  ('pg_catalog', 'stcs_datashare_changes_producer'),
#  ('pg_catalog', 'stcs_datashare_dsms'),
#  ('pg_catalog', 'stcs_datashare_request_consumer'),
#  ('pg_catalog', 'stcs_datashare_request_producer'),
#  ('pg_catalog', 'stcs_datasharing_log'),
#  ('pg_catalog', 'stcs_db_isolation_level'),
#  ('pg_catalog', 'stcs_ddltext'),
#  ('pg_catalog', 'stcs_dead_tuples_stats'),
#  ('pg_catalog', 'stcs_default_iam_usage'),
#  ('pg_catalog', 'stcs_delete'),
#  ('pg_catalog', 'stcs_delete_tag_throttle'),
#  ('pg_catalog', 'stcs_dirty_table_metadata'),
#  ('pg_catalog', 'stcs_disk_cache_megablock_stats'),
#  ('pg_catalog', 'stcs_disk_cache_stats'),
#  ('pg_catalog', 'stcs_disk_cache_write'),
#  ('pg_catalog', 'stcs_disk_extent_splits'),
#  ('pg_catalog', 'stcs_disk_failures'),
#  ('pg_catalog', 'stcs_disk_full_diag'),
#  ('pg_catalog', 'stcs_disk_speeds'),
#  ('pg_catalog', 'stcs_disk_topology'),
#  ('pg_catalog', 'stcs_diskman_query_block_read_stats'),
#  ('pg_catalog', 'stcs_disks_blocks_stats'),
#  ('pg_catalog', 'stcs_dist'),
#  ('pg_catalog', 'stcs_doryc_log'),
#  ('pg_catalog', 'stcs_dropped_replication'),
#  ('pg_catalog', 'stcs_dynamodb_error'),
#  ('pg_catalog', 'stcs_dynamodb_restore'),
#  ('pg_catalog', 'stcs_epsilon_metadata_events'),
#  ('pg_catalog', 'stcs_error'),
#  ('pg_catalog', 'stcs_event_trace'),
#  ('pg_catalog', 'stcs_exec_state'),
#  ('pg_catalog', 'stcs_explain'),
#  ('pg_catalog', 'stcs_external_catalog_calls'),
#  ('pg_catalog', 'stcs_external_query_detail_base'),
#  ('pg_catalog', 'stcs_fabric_stats'),
#  ('pg_catalog', 'stcs_federated_calls'),
#  ('pg_catalog', 'stcs_federated_query'),
#  ('pg_catalog', 'stcs_federated_trace'),
#  ('pg_catalog', 'stcs_fetchers'),
#  ('pg_catalog', 'stcs_file_scan'),
#  ('pg_catalog', 'stcs_freed_disk_addrs'),
#  ('pg_catalog', 'stcs_function_column_linker'),
#  ('pg_catalog', 'stcs_ghost_buffer_stats'),
#  ('pg_catalog', 'stcs_ght_hash_flatten'),
#  ('pg_catalog', 'stcs_ght_hash_partitions'),
#  ('pg_catalog', 'stcs_guc'),
#  ('pg_catalog', 'stcs_guid_cache_metrics'),
#  ('pg_catalog', 'stcs_hash'),
#  ('pg_catalog', 'stcs_hash_partitions'),
#  ('pg_catalog', 'stcs_hashjoin'),
#  ('pg_catalog', 'stcs_hashjoin_partitions'),
#  ('pg_catalog', 'stcs_hdr_integrity_error'),
#  ('pg_catalog', 'stcs_hllsketch_column_linker'),
#  ('pg_catalog', 'stcs_hllsketch_function'),
#  ('pg_catalog', 'stcs_hllsketch_query'),
#  ('pg_catalog', 'stcs_hot_tables_qpd_stats'),
#  ('pg_catalog', 'stcs_inc_commit_stats_instrumentation'),
#  ('pg_catalog', 'stcs_incremental_resize_state'),
#  ('pg_catalog', 'stcs_inflight'),
#  ('pg_catalog', 'stcs_insert'),
#  ('pg_catalog', 'stcs_internal_query_details'),
#  ('pg_catalog', 'stcs_invalid_replication'),
#  ('pg_catalog', 'stcs_invariant'),
#  ('pg_catalog', 'stcs_io_error'),
#  ('pg_catalog', 'stcs_io_iscsi_monitor'),
#  ('pg_catalog', 'stcs_io_perf'),
#  ('pg_catalog', 'stcs_io_stat'),
#  ('pg_catalog', 'stcs_kinesis_outbound_requests'),
#  ('pg_catalog', 'stcs_kinesis_scan_errors'),
#  ('pg_catalog', 'stcs_kinesis_scan_states'),
#  ('pg_catalog', 'stcs_lambda_client'),
#  ('pg_catalog', 'stcs_lambda_execution_logs'),
#  ('pg_catalog', 'stcs_lambda_invocation_error'),
#  ('pg_catalog', 'stcs_lbc_events'),
#  ('pg_catalog', 'stcs_leader_control'),
#  ('pg_catalog', 'stcs_leader_snapshot'),
#  ('pg_catalog', 'stcs_limit'),
#  ('pg_catalog', 'stcs_load_commits'),
#  ('pg_catalog', 'stcs_load_error_info'),
#  ('pg_catalog', 'stcs_load_errors'),
#  ('pg_catalog', 'stcs_load_history_base'),
#  ('pg_catalog', 'stcs_load_options'),
#  ('pg_catalog', 'stcs_load_trace'),
#  ('pg_catalog', 'stcs_loaderror_detail'),
#  ('pg_catalog', 'stcs_lwlock'),
#  ('pg_catalog', 'stcs_mark_partitions'),
#  ('pg_catalog', 'stcs_mem_alloc_history'),
#  ('pg_catalog', 'stcs_mem_block_details'),
#  ('pg_catalog', 'stcs_mem_freelist'),
#  ('pg_catalog', 'stcs_mem_heavy_hitters'),
#  ('pg_catalog', 'stcs_mem_leaks'),
#  ('pg_catalog', 'stcs_mem_ops_counts'),
#  ('pg_catalog', 'stcs_memefficiency'),
#  ('pg_catalog', 'stcs_memhisto'),
#  ('pg_catalog', 'stcs_memory_pressure_actions'),
#  ('pg_catalog', 'stcs_memory_pressure_state'),
#  ('pg_catalog', 'stcs_memory_pressure_suspects'),
#  ('pg_catalog', 'stcs_merge'),
#  ('pg_catalog', 'stcs_mergejoin'),
#  ('pg_catalog', 'stcs_metadata_step'),
#  ('pg_catalog', 'stcs_minmax_errors'),
#  ('pg_catalog', 'stcs_misc_sys_stat'),
#  ('pg_catalog', 'stcs_ml_create_model_log'),
#  ('pg_catalog', 'stcs_ml_dlr_usage'),
#  ('pg_catalog', 'stcs_ml_log'),
#  ('pg_catalog', 'stcs_ml_manager_log'),
#  ('pg_catalog', 'stcs_ml_model_stats'),
#  ('pg_catalog', 'stcs_ml_processing_log'),
#  ('pg_catalog', 'stcs_ml_sagemaker_error'),
#  ('pg_catalog', 'stcs_ml_sagemaker_request'),
#  ('pg_catalog', 'stcs_mmf_details'),
#  ('pg_catalog', 'stcs_monitoring_logs_internal'),
#  ('pg_catalog', 'stcs_multi_statement_violations'),
#  ('pg_catalog', 'stcs_mutex_contention'),
#  ('pg_catalog', 'stcs_mv_aqmv'),
#  ('pg_catalog', 'stcs_mv_refresh'),
#  ('pg_catalog', 'stcs_mv_state'),
#  ('pg_catalog', 'stcs_nestloop'),
#  ('pg_catalog', 'stcs_net_stat'),
#  ('pg_catalog', 'stcs_netmon_ip'),
#  ('pg_catalog', 'stcs_netmon_mac'),
#  ('pg_catalog', 'stcs_network_throttle'),
#  ('pg_catalog', 'stcs_nft_query_reissue'),
#  ('pg_catalog', 'stcs_nft_session_persistence'),
#  ('pg_catalog', 'stcs_nft_statement_replay_status'),
#  ('pg_catalog', 'stcs_node_failovers'),
#  ('pg_catalog', 'stcs_nullyze'),
#  ('pg_catalog', 'stcs_omnisql_error'),
#  ('pg_catalog', 'stcs_omnisql_rewrite_rules'),
#  ('pg_catalog', 'stcs_omnisql_rewrite_stats'),
#  ('pg_catalog', 'stcs_parse'),
#  ('pg_catalog', 'stcs_perf_comm'),
#  ('pg_catalog', 'stcs_perf_histograms'),
#  ('pg_catalog', 'stcs_persisted_sessions_on_disk'),
#  ('pg_catalog', 'stcs_pg_wal_stats'),
#  ('pg_catalog', 'stcs_pinned_blocks'),
#  ('pg_catalog', 'stcs_plan_explain'),
#  ('pg_catalog', 'stcs_plan_explain_props'),
#  ('pg_catalog', 'stcs_plan_explain_tree'),
#  ('pg_catalog', 'stcs_plan_info'),
#  ('pg_catalog', 'stcs_plan_perf'),
#  ('pg_catalog', 'stcs_plan_qid_map'),
#  ('pg_catalog', 'stcs_plan_querytext'),
#  ('pg_catalog', 'stcs_plan_rule_stats'),
#  ('pg_catalog', 'stcs_plan_state'),
#  ('pg_catalog', 'stcs_prefetch_stats'),
#  ('pg_catalog', 'stcs_print'),
#  ('pg_catalog', 'stcs_proc_stat'),
#  ('pg_catalog', 'stcs_process_state'),
#  ('pg_catalog', 'stcs_project'),
#  ('pg_catalog', 'stcs_query'),
#  ('pg_catalog', 'stcs_query_block_stats'),
#  ('pg_catalog', 'stcs_query_concurrency_scaling_decision'),
#  ('pg_catalog', 'stcs_query_concurrency_scaling_fail_reasons'),
#  ('pg_catalog', 'stcs_query_detail'),
#  ('pg_catalog', 'stcs_query_execution_time_prediction'),
#  ('pg_catalog', 'stcs_query_heap_memory_stats_by_component'),
#  ('pg_catalog', 'stcs_query_heap_memory_usage'),
#  ('pg_catalog', 'stcs_query_internal'),
#  ('pg_catalog', 'stcs_query_mem_leaks'),
#  ('pg_catalog', 'stcs_query_mem_stats'),
#  ('pg_catalog', 'stcs_query_mem_stats_by_type'),
#  ('pg_catalog', 'stcs_query_memory'),
#  ('pg_catalog', 'stcs_query_memory_cheating'),
#  ('pg_catalog', 'stcs_query_metrics'),
#  ('pg_catalog', 'stcs_query_prediction'),
#  ('pg_catalog', 'stcs_query_step_times'),
#  ('pg_catalog', 'stcs_query_transmit_metrics'),
#  ('pg_catalog', 'stcs_query_tx_metrics'),
#  ('pg_catalog', 'stcs_querytext'),
#  ('pg_catalog', 'stcs_querytext_internal'),
#  ('pg_catalog', 'stcs_range_insert'),
#  ('pg_catalog', 'stcs_redcat_journal_gc_info'),
#  ('pg_catalog', 'stcs_redshift_proxy_log'),
#  ('pg_catalog', 'stcs_rehydration_metrics'),
#  ('pg_catalog', 'stcs_remote_access_blocklist'),
#  ('pg_catalog', 'stcs_replacements'),
#  ('pg_catalog', 'stcs_rereplication'),
#  ('pg_catalog', 'stcs_res_leaks'),
#  ('pg_catalog', 'stcs_restarted_sessions'),
#  ('pg_catalog', 'stcs_restarted_sessions_internal'),
#  ('pg_catalog', 'stcs_result_cache_history'),
#  ('pg_catalog', 'stcs_result_cache_stats'),
#  ('pg_catalog', 'stcs_return'),
#  ('pg_catalog', 'stcs_right_sizing'),
#  ('pg_catalog', 'stcs_rlf_scan'),
#  ('pg_catalog', 'stcs_rls_applied_policy'),
#  ('pg_catalog', 'stcs_rms_calls'),
#  ('pg_catalog', 'stcs_rpc'),
#  ('pg_catalog', 'stcs_rtf_save'),
#  ('pg_catalog', 'stcs_rtf_stats'),
#  ('pg_catalog', 'stcs_rtree'),
#  ('pg_catalog', 'stcs_s3_commit_leak'),
#  ('pg_catalog', 'stcs_s3_write_block_debug'),
#  ('pg_catalog', 'stcs_s3client'),
#  ('pg_catalog', 'stcs_s3client_error'),
#  ('pg_catalog', 'stcs_s3client_trace'),
#  ('pg_catalog', 'stcs_s3commit_ddb_entry'),
#  ('pg_catalog', 'stcs_s3commit_stats'),
#  ('pg_catalog', 'stcs_s3list'),
#  ('pg_catalog', 'stcs_s3log'),
#  ('pg_catalog', 'stcs_s3partition_elimination'),
#  ('pg_catalog', 'stcs_s3partition_predicate'),
#  ('pg_catalog', 'stcs_s3pushdown'),
#  ('pg_catalog', 'stcs_s3query'),
#  ('pg_catalog', 'stcs_s3query_billing_trace'),
#  ('pg_catalog', 'stcs_s3query_metering'),
#  ('pg_catalog', 'stcs_s3requests'),
#  ('pg_catalog', 'stcs_s3retries'),
#  ('pg_catalog', 'stcs_sample'),
#  ('pg_catalog', 'stcs_save'),
#  ('pg_catalog', 'stcs_sb_recovery'),
#  ('pg_catalog', 'stcs_scan'),
#  ('pg_catalog', 'stcs_scan_range_stats'),
#  ('pg_catalog', 'stcs_schema_quota_ddl'),
#  ('pg_catalog', 'stcs_schema_quota_violations'),
#  ('pg_catalog', 'stcs_seg_completed_notify'),
#  ('pg_catalog', 'stcs_segment_ends_cleanly'),
#  ('pg_catalog', 'stcs_segment_starts'),
#  ('pg_catalog', 'stcs_sem_pool'),
#  ('pg_catalog', 'stcs_sem_stat'),
#  ('pg_catalog', 'stcs_sem_usage'),
#  ('pg_catalog', 'stcs_serial_safety_net'),
#  ('pg_catalog', 'stcs_server_write_timings'),
#  ('pg_catalog', 'stcs_services_control_metrics'),
#  ('pg_catalog', 'stcs_session_state'),
#  ('pg_catalog', 'stcs_sessions'),
#  ('pg_catalog', 'stcs_shadow_table_commit'),
#  ('pg_catalog', 'stcs_skr_scan_metrics'),
#  ('pg_catalog', 'stcs_small_table_convert_event'),
#  ('pg_catalog', 'stcs_smfaults'),
#  ('pg_catalog', 'stcs_smfaults_cleared'),
#  ('pg_catalog', 'stcs_smfaults_mval'),
#  ('pg_catalog', 'stcs_smfaults_overflow'),
#  ('pg_catalog', 'stcs_smlog'),
#  ('pg_catalog', 'stcs_snapshotbackup'),
#  ('pg_catalog', 'stcs_sort'),
#  ('pg_catalog', 'stcs_sorted_checker'),
#  ('pg_catalog', 'stcs_sorted_checker_leader'),
#  ('pg_catalog', 'stcs_spatial_column_linker'),
#  ('pg_catalog', 'stcs_spatial_function'),
#  ('pg_catalog', 'stcs_spatial_index'),
#  ('pg_catalog', 'stcs_spatial_join'),
#  ('pg_catalog', 'stcs_spatial_query'),
#  ('pg_catalog', 'stcs_spatial_simplify'),
#  ('pg_catalog', 'stcs_spectrum_cache_error'),
#  ('pg_catalog', 'stcs_spectrum_scan_error'),
#  ('pg_catalog', 'stcs_sshclient_error'),
#  ('pg_catalog', 'stcs_ssn_violation'),
#  ('pg_catalog', 'stcs_stack_trace'),
#  ('pg_catalog', 'stcs_stack_traces'),
#  ('pg_catalog', 'stcs_startup_metrics'),
#  ('pg_catalog', 'stcs_step_parse'),
#  ('pg_catalog', 'stcs_steps'),
#  ('pg_catalog', 'stcs_stored_proc_call'),
#  ('pg_catalog', 'stcs_stored_proc_call_map'),
#  ('pg_catalog', 'stcs_stored_proc_messages'),
#  ('pg_catalog', 'stcs_stream_segs'),
#  ('pg_catalog', 'stcs_super_column_linker'),
#  ('pg_catalog', 'stcs_super_function'),
#  ('pg_catalog', 'stcs_super_query'),
#  ('pg_catalog', 'stcs_superblock'),
#  ('pg_catalog', 'stcs_superblock_integrity_error'),
#  ('pg_catalog', 'stcs_superblock_vacuum'),
#  ('pg_catalog', 'stcs_swap'),
#  ('pg_catalog', 'stcs_system_abort_txn'),
#  ('pg_catalog', 'stcs_system_state'),
#  ('pg_catalog', 'stcs_table_mutex'),
#  ('pg_catalog', 'stcs_table_partition_qpd_stats'),
#  ('pg_catalog', 'stcs_table_partition_scan'),
#  ('pg_catalog', 'stcs_table_partitions_hotness_stats'),
#  ('pg_catalog', 'stcs_terminate'),
#  ('pg_catalog', 'stcs_tiered_storage_controller'),
#  ('pg_catalog', 'stcs_tiered_storage_s3_blocks'),
#  ('pg_catalog', 'stcs_tombstone'),
#  ('pg_catalog', 'stcs_tr_conflict'),
#  ('pg_catalog', 'stcs_transaction_read_write_set'),
#  ('pg_catalog', 'stcs_udf'),
#  ('pg_catalog', 'stcs_udf_compile_error'),
#  ('pg_catalog', 'stcs_udf_log'),
#  ('pg_catalog', 'stcs_udf_trace'),
#  ('pg_catalog', 'stcs_undo_transactions'),
#  ('pg_catalog', 'stcs_undone'),
#  ('pg_catalog', 'stcs_unique'),
#  ('pg_catalog', 'stcs_unload_history_base'),
#  ('pg_catalog', 'stcs_unload_log'),
#  ('pg_catalog', 'stcs_unload_options'),
#  ('pg_catalog', 'stcs_unnest'),
#  ('pg_catalog', 'stcs_usage_control'),
#  ('pg_catalog', 'stcs_user_load_error_detail'),
#  ('pg_catalog', 'stcs_user_query_history'),
#  ('pg_catalog', 'stcs_user_query_rewrite'),
#  ('pg_catalog', 'stcs_userlog'),
#  ('pg_catalog', 'stcs_utilitytext'),
#  ('pg_catalog', 'stcs_vacuum'),
#  ('pg_catalog', 'stcs_vacuum_detail'),
#  ('pg_catalog', 'stcs_vacuum_history'),
#  ('pg_catalog', 'stcs_vacuum_scan_query_usage'),
#  ('pg_catalog', 'stcs_varbyte_column_linker'),
#  ('pg_catalog', 'stcs_varbyte_function'),
#  ('pg_catalog', 'stcs_varbyte_query'),
#  ('pg_catalog', 'stcs_vec_scan_stats'),
#  ('pg_catalog', 'stcs_version'),
#  ('pg_catalog', 'stcs_volt_tt_sizes'),
#  ('pg_catalog', 'stcs_vpid'),
#  ('pg_catalog', 'stcs_vpid_error'),
#  ('pg_catalog', 'stcs_wam_lifecycle'),
#  ('pg_catalog', 'stcs_warning'),
#  ('pg_catalog', 'stcs_window'),
#  ('pg_catalog', 'stcs_wlm_auto_concurrency'),
#  ('pg_catalog', 'stcs_wlm_error'),
#  ('pg_catalog', 'stcs_wlm_query'),
#  ('pg_catalog', 'stcs_wlm_query_preemption'),
#  ('pg_catalog', 'stcs_wlm_rule_action'),
#  ('pg_catalog', 'stcs_wlm_service_class_config'),
#  ('pg_catalog', 'stcs_wlm_trace'),
#  ('pg_catalog', 'stcs_wlm_trace_query_state'),
#  ('pg_catalog', 'stcs_xid_consumption_rate'),
#  ('pg_catalog', 'stcs_xregion_billing_error'),
#  ('pg_catalog', 'stcs_xregion_metering'),
#  ('pg_catalog', 'stcs_xrestore'),
#  ('pg_catalog', 'stcs_xrestore_alter_distkey'),
#  ('pg_catalog', 'stcs_xrestore_cluster_level_distkey_tables'),
#  ('pg_catalog', 'stl_abort_idle'),
#  ('pg_catalog', 'stl_aggr'),
#  ('pg_catalog', 'stl_aggr_distinct'),
#  ('pg_catalog', 'stl_alert_event_log'),
#  ('pg_catalog', 'stl_alert_messages'),
#  ('pg_catalog', 'stl_alter_column_encode_events'),
#  ('pg_catalog', 'stl_alter_column_events'),
#  ('pg_catalog', 'stl_alter_dist_sort'),
#  ('pg_catalog', 'stl_alter_sortkey_events'),
#  ('pg_catalog', 'stl_analyze'),
#  ('pg_catalog', 'stl_analyze_compression'),
#  ('pg_catalog', 'stl_aqua_pushdown'),
#  ('pg_catalog', 'stl_aqua_requests'),
#  ('pg_catalog', 'stl_arcadia_billing_log'),
#  ('pg_catalog', 'stl_arcadia_billing_ris_reports'),
#  ('pg_catalog', 'stl_arcadia_billing_xact_log'),
#  ('pg_catalog', 'stl_arcadia_concurrency_scaling_usage'),
#  ('pg_catalog', 'stl_arcadia_concurrency_scaling_usage_error'),
#  ('pg_catalog', 'stl_arcadia_main_usage'),
#  ('pg_catalog', 'stl_arcadia_main_usage_error'),
#  ('pg_catalog', 'stl_auto_alter_worker_event'),
#  ('pg_catalog', 'stl_auto_dispatcher_wlm_occupancy'),
#  ('pg_catalog', 'stl_auto_maintenance'),
#  ('pg_catalog', 'stl_auto_maintenance_worker'),
#  ('pg_catalog', 'stl_auto_task_events'),
#  ('pg_catalog', 'stl_auto_worker_levels'),
#  ('pg_catalog', 'stl_autovacuum_detail'),
#  ('pg_catalog', 'stl_autovacuum_skip_reason'),
#  ('pg_catalog', 'stl_awsclient_error'),
#  ('pg_catalog', 'stl_background_monitor'),
#  ('pg_catalog', 'stl_background_tasks'),
#  ('pg_catalog', 'stl_backtrace'),
#  ('pg_catalog', 'stl_backup_compute'),
#  ('pg_catalog', 'stl_backup_leader'),
#  ('pg_catalog', 'stl_bcast'),
#  ('pg_catalog', 'stl_bkg_compile_info'),
#  ('pg_catalog', 'stl_blf_efficiency'),
#  ('pg_catalog', 'stl_block_access_errors'),
#  ('pg_catalog', 'stl_block_integrity_error'),
#  ('pg_catalog', 'stl_block_io_metrics'),
#  ('pg_catalog', 'stl_block_needs_recovery'),
#  ('pg_catalog', 'stl_block_pins'),
#  ('pg_catalog', 'stl_block_priority_based_rereplication'),
#  ('pg_catalog', 'stl_blocklist'),
#  ('pg_catalog', 'stl_bootstrap'),
#  ('pg_catalog', 'stl_burst_async_mark'),
#  ('pg_catalog', 'stl_burst_connection'),
#  ('pg_catalog', 'stl_burst_manager_personalization'),
#  ('pg_catalog', 'stl_burst_manager_refresh'),
#  ('pg_catalog', 'stl_burst_prepare'),
#  ('pg_catalog', 'stl_burst_query_execution'),
#  ('pg_catalog', 'stl_burst_refresh'),
#  ('pg_catalog', 'stl_burst_service_client'),
#  ('pg_catalog', 'stl_burst_write_block_header_trace'),
#  ('pg_catalog', 'stl_burst_write_exec'),
#  ('pg_catalog', 'stl_burst_write_query_event'),
#  ('pg_catalog', 'stl_cache_policy_stats'),
#  ('pg_catalog', 'stl_catalog_bloat'),
#  ('pg_catalog', 'stl_catalog_bufmgr_stats'),
#  ('pg_catalog', 'stl_catalog_rebuild_info'),
#  ('pg_catalog', 'stl_catalog_rebuild_worker'),
#  ('pg_catalog', 'stl_catalog_scan_metrics'),
#  ('pg_catalog', 'stl_clear_reps'),
#  ('pg_catalog', 'stl_client_write_timings'),
#  ('pg_catalog', 'stl_cluster_blocks_stats'),
#  ('pg_catalog', 'stl_cmd_requires_top_xact'),
#  ('pg_catalog', 'stl_codegen'),
#  ('pg_catalog', 'stl_column_access_metrics'),
#  ('pg_catalog', 'stl_column_errors'),
#  ('pg_catalog', 'stl_column_stats'),
#  ('pg_catalog', 'stl_comm_capture'),
#  ('pg_catalog', 'stl_comm_diag'),
#  ('pg_catalog', 'stl_comm_diag_errors'),
#  ('pg_catalog', 'stl_comm_excess'),
#  ('pg_catalog', 'stl_comm_integrity_error'),
#  ('pg_catalog', 'stl_comm_pkt_latency'),
#  ('pg_catalog', 'stl_comm_pkt_oob_count'),
#  ('pg_catalog', 'stl_comm_pkt_sent_count'),
#  ('pg_catalog', 'stl_comm_rexmit'),
#  ('pg_catalog', 'stl_comm_rexmit_histogram'),
#  ('pg_catalog', 'stl_command_result'),
#  ('pg_catalog', 'stl_command_start'),
#  ('pg_catalog', 'stl_commit_checkpoint'),
#  ('pg_catalog', 'stl_commit_internal_stats'),
#  ('pg_catalog', 'stl_commit_regions'),
#  ('pg_catalog', 'stl_commit_stats'),
#  ('pg_catalog', 'stl_committed_txn'),
#  ('pg_catalog', 'stl_compile_info'),
#  ('pg_catalog', 'stl_compile_print'),
#  ('pg_catalog', 'stl_compile_service'),
#  ('pg_catalog', 'stl_complyze'),
#  ('pg_catalog', 'stl_concurrency_scaling_query_mapping'),
#  ('pg_catalog', 'stl_concurrency_scaling_usage'),
#  ('pg_catalog', 'stl_concurrency_scaling_usage_error'),
#  ('pg_catalog', 'stl_config'),
#  ('pg_catalog', 'stl_config_chooser'),
#  ('pg_catalog', 'stl_config_history'),
#  ('pg_catalog', 'stl_connection_log'),
#  ('pg_catalog', 'stl_consistency'),
#  ('pg_catalog', 'stl_core_stat'),
#  ('pg_catalog', 'stl_cost_control_updates'),
#  ('pg_catalog', 'stl_cqilog'),
#  ('pg_catalog', 'stl_create_replication'),
#  ('pg_catalog', 'stl_dag_cleanup'),
#  ('pg_catalog', 'stl_datashare_changes_consumer'),
#  ('pg_catalog', 'stl_datashare_changes_producer'),
#  ('pg_catalog', 'stl_datashare_dsms'),
#  ('pg_catalog', 'stl_datashare_request_consumer'),
#  ('pg_catalog', 'stl_datashare_request_producer'),
#  ('pg_catalog', 'stl_datasharing_log'),
#  ('pg_catalog', 'stl_db_isolation_level'),
#  ('pg_catalog', 'stl_ddltext'),
#  ('pg_catalog', 'stl_dead_tuples_stats'),
#  ('pg_catalog', 'stl_default_iam_usage'),
#  ('pg_catalog', 'stl_delete'),
#  ('pg_catalog', 'stl_delete_tag_throttle'),
#  ('pg_catalog', 'stl_dirty_table_metadata'),
#  ('pg_catalog', 'stl_disk_cache_megablock_stats'),
#  ('pg_catalog', 'stl_disk_cache_stats'),
#  ('pg_catalog', 'stl_disk_cache_write'),
#  ('pg_catalog', 'stl_disk_extent_splits'),
#  ('pg_catalog', 'stl_disk_failures'),
#  ('pg_catalog', 'stl_disk_full_diag'),
#  ('pg_catalog', 'stl_disk_speeds'),
#  ('pg_catalog', 'stl_disk_topology'),
#  ('pg_catalog', 'stl_diskman_query_block_read_stats'),
#  ('pg_catalog', 'stl_disks_blocks_stats'),
#  ('pg_catalog', 'stl_dist'),
#  ('pg_catalog', 'stl_doryc_log'),
#  ('pg_catalog', 'stl_dropped_replication'),
#  ('pg_catalog', 'stl_dynamodb_error'),
#  ('pg_catalog', 'stl_dynamodb_restore'),
#  ('pg_catalog', 'stl_epsilon_metadata_events'),
#  ('pg_catalog', 'stl_error'),
#  ('pg_catalog', 'stl_event_trace'),
#  ('pg_catalog', 'stl_exec_state'),
#  ('pg_catalog', 'stl_explain'),
#  ('pg_catalog', 'stl_external_catalog_calls'),
#  ('pg_catalog', 'stl_external_query_detail_base'),
#  ('pg_catalog', 'stl_fabric_stats'),
#  ('pg_catalog', 'stl_federated_calls'),
#  ('pg_catalog', 'stl_federated_query'),
#  ('pg_catalog', 'stl_federated_trace'),
#  ('pg_catalog', 'stl_fetchers'),
#  ('pg_catalog', 'stl_file_scan'),
#  ('pg_catalog', 'stl_freed_disk_addrs'),
#  ('pg_catalog', 'stl_function_column_linker'),
#  ('pg_catalog', 'stl_ghost_buffer_stats'),
#  ('pg_catalog', 'stl_ght_hash_flatten'),
#  ('pg_catalog', 'stl_ght_hash_partitions'),
#  ('pg_catalog', 'stl_guc'),
#  ('pg_catalog', 'stl_guid_cache_metrics'),
#  ('pg_catalog', 'stl_hash'),
#  ('pg_catalog', 'stl_hash_partitions'),
#  ('pg_catalog', 'stl_hashjoin'),
#  ('pg_catalog', 'stl_hashjoin_partitions'),
#  ('pg_catalog', 'stl_hdr_integrity_error'),
#  ('pg_catalog', 'stl_hllsketch_column_linker'),
#  ('pg_catalog', 'stl_hllsketch_function'),
#  ('pg_catalog', 'stl_hllsketch_query'),
#  ('pg_catalog', 'stl_hot_tables_qpd_stats'),
#  ('pg_catalog', 'stl_inc_commit_stats_instrumentation'),
#  ('pg_catalog', 'stl_incremental_resize_state'),
#  ('pg_catalog', 'stl_inflight'),
#  ('pg_catalog', 'stl_insert'),
#  ('pg_catalog', 'stl_internal_query_details'),
#  ('pg_catalog', 'stl_invalid_replication'),
#  ('pg_catalog', 'stl_invariant'),
#  ('pg_catalog', 'stl_io_error'),
#  ('pg_catalog', 'stl_io_iscsi_monitor'),
#  ('pg_catalog', 'stl_io_perf'),
#  ('pg_catalog', 'stl_io_stat'),
#  ('pg_catalog', 'stl_kinesis_outbound_requests'),
#  ('pg_catalog', 'stl_kinesis_scan_errors'),
#  ('pg_catalog', 'stl_kinesis_scan_states'),
#  ('pg_catalog', 'stl_lambda_client'),
#  ('pg_catalog', 'stl_lambda_execution_logs'),
#  ('pg_catalog', 'stl_lambda_invocation_error'),
#  ('pg_catalog', 'stl_lbc_events'),
#  ('pg_catalog', 'stl_leader_control'),
#  ('pg_catalog', 'stl_leader_snapshot'),
#  ('pg_catalog', 'stl_limit'),
#  ('pg_catalog', 'stl_load_commits'),
#  ('pg_catalog', 'stl_load_error_info'),
#  ('pg_catalog', 'stl_load_errors'),
#  ('pg_catalog', 'stl_load_history_base'),
#  ('pg_catalog', 'stl_load_options'),
#  ('pg_catalog', 'stl_load_trace'),
#  ('pg_catalog', 'stl_loaderror_detail'),
#  ('pg_catalog', 'stl_lwlock'),
#  ('pg_catalog', 'stl_mark_partitions'),
#  ('pg_catalog', 'stl_mem_alloc_history'),
#  ('pg_catalog', 'stl_mem_block_details'),
#  ('pg_catalog', 'stl_mem_freelist'),
#  ('pg_catalog', 'stl_mem_heavy_hitters'),
#  ('pg_catalog', 'stl_mem_leaks'),
#  ('pg_catalog', 'stl_mem_ops_counts'),
#  ('pg_catalog', 'stl_memefficiency'),
#  ('pg_catalog', 'stl_memhisto'),
#  ('pg_catalog', 'stl_memory_pressure_actions'),
#  ('pg_catalog', 'stl_memory_pressure_state'),
#  ('pg_catalog', 'stl_memory_pressure_suspects'),
#  ('pg_catalog', 'stl_merge'),
#  ('pg_catalog', 'stl_mergejoin'),
#  ('pg_catalog', 'stl_metadata_step'),
#  ('pg_catalog', 'stl_minmax_errors'),
#  ('pg_catalog', 'stl_misc_sys_stat'),
#  ('pg_catalog', 'stl_ml_create_model_log'),
#  ('pg_catalog', 'stl_ml_dlr_usage'),
#  ('pg_catalog', 'stl_ml_log'),
#  ('pg_catalog', 'stl_ml_manager_log'),
#  ('pg_catalog', 'stl_ml_model_stats'),
#  ('pg_catalog', 'stl_ml_processing_log'),
#  ('pg_catalog', 'stl_ml_sagemaker_error'),
#  ('pg_catalog', 'stl_ml_sagemaker_request'),
#  ('pg_catalog', 'stl_mmf_details'),
#  ('pg_catalog', 'stl_monitoring_logs_internal'),
#  ('pg_catalog', 'stl_multi_statement_violations'),
#  ('pg_catalog', 'stl_mutex_contention'),
#  ('pg_catalog', 'stl_mv_aqmv'),
#  ('pg_catalog', 'stl_mv_refresh'),
#  ('pg_catalog', 'stl_mv_state'),
#  ('pg_catalog', 'stl_nestloop'),
#  ('pg_catalog', 'stl_net_stat'),
#  ('pg_catalog', 'stl_netmon_ip'),
#  ('pg_catalog', 'stl_netmon_mac'),
#  ('pg_catalog', 'stl_network_throttle'),
#  ('pg_catalog', 'stl_nft_query_reissue'),
#  ('pg_catalog', 'stl_nft_session_persistence'),
#  ('pg_catalog', 'stl_nft_statement_replay_status'),
#  ('pg_catalog', 'stl_node_failovers'),
#  ('pg_catalog', 'stl_nullyze'),
#  ('pg_catalog', 'stl_omnisql_error'),
#  ('pg_catalog', 'stl_omnisql_rewrite_rules'),
#  ('pg_catalog', 'stl_omnisql_rewrite_stats'),
#  ('pg_catalog', 'stl_parse'),
#  ('pg_catalog', 'stl_perf_comm'),
#  ('pg_catalog', 'stl_perf_histograms'),
#  ('pg_catalog', 'stl_persisted_sessions_on_disk'),
#  ('pg_catalog', 'stl_pg_wal_stats'),
#  ('pg_catalog', 'stl_pinned_blocks'),
#  ('pg_catalog', 'stl_plan_explain'),
#  ('pg_catalog', 'stl_plan_explain_props'),
#  ('pg_catalog', 'stl_plan_explain_tree'),
#  ('pg_catalog', 'stl_plan_info'),
#  ('pg_catalog', 'stl_plan_perf'),
#  ('pg_catalog', 'stl_plan_qid_map'),
#  ('pg_catalog', 'stl_plan_querytext'),
#  ('pg_catalog', 'stl_plan_rule_stats'),
#  ('pg_catalog', 'stl_plan_state'),
#  ('pg_catalog', 'stl_prefetch_stats'),
#  ('pg_catalog', 'stl_print'),
#  ('pg_catalog', 'stl_proc_stat'),
#  ('pg_catalog', 'stl_process_state'),
#  ('pg_catalog', 'stl_project'),
#  ('pg_catalog', 'stl_query'),
#  ('pg_catalog', 'stl_query_block_stats'),
#  ('pg_catalog', 'stl_query_concurrency_scaling_decision'),
#  ('pg_catalog', 'stl_query_concurrency_scaling_fail_reasons'),
#  ('pg_catalog', 'stl_query_detail'),
#  ('pg_catalog', 'stl_query_execution_time_prediction'),
#  ('pg_catalog', 'stl_query_heap_memory_stats_by_component'),
#  ('pg_catalog', 'stl_query_heap_memory_usage'),
#  ('pg_catalog', 'stl_query_internal'),
#  ('pg_catalog', 'stl_query_mem_leaks'),
#  ('pg_catalog', 'stl_query_mem_stats'),
#  ('pg_catalog', 'stl_query_mem_stats_by_type'),
#  ('pg_catalog', 'stl_query_memory'),
#  ('pg_catalog', 'stl_query_memory_cheating'),
#  ('pg_catalog', 'stl_query_metrics'),
#  ('pg_catalog', 'stl_query_prediction'),
#  ('pg_catalog', 'stl_query_step_times'),
#  ('pg_catalog', 'stl_query_transmit_metrics'),
#  ('pg_catalog', 'stl_query_tx_metrics'),
#  ('pg_catalog', 'stl_querytext'),
#  ('pg_catalog', 'stl_querytext_internal'),
#  ('pg_catalog', 'stl_range_insert'),
#  ('pg_catalog', 'stl_redcat_journal_gc_info'),
#  ('pg_catalog', 'stl_redshift_proxy_log'),
#  ('pg_catalog', 'stl_rehydration_metrics'),
#  ('pg_catalog', 'stl_remote_access_blocklist'),
#  ('pg_catalog', 'stl_replacements'),
#  ('pg_catalog', 'stl_rereplication'),
#  ('pg_catalog', 'stl_res_leaks'),
#  ('pg_catalog', 'stl_restarted_sessions'),
#  ('pg_catalog', 'stl_restarted_sessions_internal'),
#  ('pg_catalog', 'stl_result_cache_history'),
#  ('pg_catalog', 'stl_result_cache_stats'),
#  ('pg_catalog', 'stl_return'),
#  ('pg_catalog', 'stl_right_sizing'),
#  ('pg_catalog', 'stl_rlf_scan'),
#  ('pg_catalog', 'stl_rls_applied_policy'),
#  ('pg_catalog', 'stl_rms_calls'),
#  ('pg_catalog', 'stl_rpc'),
#  ('pg_catalog', 'stl_rtf_save'),
#  ('pg_catalog', 'stl_rtf_stats'),
#  ('pg_catalog', 'stl_rtree'),
#  ('pg_catalog', 'stl_s3_commit_leak'),
#  ('pg_catalog', 'stl_s3_write_block_debug'),
#  ('pg_catalog', 'stl_s3client'),
#  ('pg_catalog', 'stl_s3client_error'),
#  ('pg_catalog', 'stl_s3client_trace'),
#  ('pg_catalog', 'stl_s3commit_ddb_entry'),
#  ('pg_catalog', 'stl_s3commit_stats'),
#  ('pg_catalog', 'stl_s3list'),
#  ('pg_catalog', 'stl_s3log'),
#  ('pg_catalog', 'stl_s3partition_elimination'),
#  ('pg_catalog', 'stl_s3partition_predicate'),
#  ('pg_catalog', 'stl_s3pushdown'),
#  ('pg_catalog', 'stl_s3query'),
#  ('pg_catalog', 'stl_s3query_billing_trace'),
#  ('pg_catalog', 'stl_s3query_metering'),
#  ('pg_catalog', 'stl_s3requests'),
#  ('pg_catalog', 'stl_s3retries'),
#  ('pg_catalog', 'stl_sample'),
#  ('pg_catalog', 'stl_save'),
#  ('pg_catalog', 'stl_sb_recovery'),
#  ('pg_catalog', 'stl_scan'),
#  ('pg_catalog', 'stl_scan_range_stats'),
#  ('pg_catalog', 'stl_schema_quota_ddl'),
#  ('pg_catalog', 'stl_schema_quota_violations'),
#  ('pg_catalog', 'stl_seg_completed_notify'),
#  ('pg_catalog', 'stl_segment_ends_cleanly'),
#  ('pg_catalog', 'stl_segment_starts'),
#  ('pg_catalog', 'stl_sem_pool'),
#  ('pg_catalog', 'stl_sem_stat'),
#  ('pg_catalog', 'stl_sem_usage'),
#  ('pg_catalog', 'stl_serial_safety_net'),
#  ('pg_catalog', 'stl_server_write_timings'),
#  ('pg_catalog', 'stl_services_control_metrics'),
#  ('pg_catalog', 'stl_session_state'),
#  ('pg_catalog', 'stl_sessions'),
#  ('pg_catalog', 'stl_shadow_table_commit'),
#  ('pg_catalog', 'stl_skr_scan_metrics'),
#  ('pg_catalog', 'stl_small_table_convert_event'),
#  ('pg_catalog', 'stl_smfaults'),
#  ('pg_catalog', 'stl_smfaults_cleared'),
#  ('pg_catalog', 'stl_smfaults_mval'),
#  ('pg_catalog', 'stl_smfaults_overflow'),
#  ('pg_catalog', 'stl_smlog'),
#  ('pg_catalog', 'stl_snapshotbackup'),
#  ('pg_catalog', 'stl_sort'),
#  ('pg_catalog', 'stl_sorted_checker'),
#  ('pg_catalog', 'stl_sorted_checker_leader'),
#  ('pg_catalog', 'stl_spatial_column_linker'),
#  ('pg_catalog', 'stl_spatial_function'),
#  ('pg_catalog', 'stl_spatial_index'),
#  ('pg_catalog', 'stl_spatial_join'),
#  ('pg_catalog', 'stl_spatial_query'),
#  ('pg_catalog', 'stl_spatial_simplify'),
#  ('pg_catalog', 'stl_spectrum_cache_error'),
#  ('pg_catalog', 'stl_spectrum_scan_error'),
#  ('pg_catalog', 'stl_sshclient_error'),
#  ('pg_catalog', 'stl_ssn_violation'),
#  ('pg_catalog', 'stl_stack_trace'),
#  ('pg_catalog', 'stl_stack_traces'),
#  ('pg_catalog', 'stl_startup_metrics'),
#  ('pg_catalog', 'stl_step_parse'),
#  ('pg_catalog', 'stl_steps'),
#  ('pg_catalog', 'stl_stored_proc_call'),
#  ('pg_catalog', 'stl_stored_proc_call_map'),
#  ('pg_catalog', 'stl_stored_proc_messages'),
#  ('pg_catalog', 'stl_stream_segs'),
#  ('pg_catalog', 'stl_super_column_linker'),
#  ('pg_catalog', 'stl_super_function'),
#  ('pg_catalog', 'stl_super_query'),
#  ('pg_catalog', 'stl_superblock'),
#  ('pg_catalog', 'stl_superblock_integrity_error'),
#  ('pg_catalog', 'stl_superblock_vacuum'),
#  ('pg_catalog', 'stl_swap'),
#  ('pg_catalog', 'stl_system_abort_txn'),
#  ('pg_catalog', 'stl_system_state'),
#  ('pg_catalog', 'stl_table_mutex'),
#  ('pg_catalog', 'stl_table_partition_qpd_stats'),
#  ('pg_catalog', 'stl_table_partition_scan'),
#  ('pg_catalog', 'stl_table_partitions_hotness_stats'),
#  ('pg_catalog', 'stl_terminate'),
#  ('pg_catalog', 'stl_tiered_storage_controller'),
#  ('pg_catalog', 'stl_tiered_storage_s3_blocks'),
#  ('pg_catalog', 'stl_tombstone'),
#  ('pg_catalog', 'stl_tr_conflict'),
#  ('pg_catalog', 'stl_transaction_read_write_set'),
#  ('pg_catalog', 'stl_udf'),
#  ('pg_catalog', 'stl_udf_compile_error'),
#  ('pg_catalog', 'stl_udf_log'),
#  ('pg_catalog', 'stl_udf_trace'),
#  ('pg_catalog', 'stl_undo_transactions'),
#  ('pg_catalog', 'stl_undone'),
#  ('pg_catalog', 'stl_unique'),
#  ('pg_catalog', 'stl_unload_history_base'),
#  ('pg_catalog', 'stl_unload_log'),
#  ('pg_catalog', 'stl_unload_options'),
#  ('pg_catalog', 'stl_unnest'),
#  ('pg_catalog', 'stl_usage_control'),
#  ('pg_catalog', 'stl_user_load_error_detail'),
#  ('pg_catalog', 'stl_user_query_history'),
#  ('pg_catalog', 'stl_user_query_rewrite'),
#  ('pg_catalog', 'stl_userlog'),
#  ('pg_catalog', 'stl_utilitytext'),
#  ('pg_catalog', 'stl_vacuum'),
#  ('pg_catalog', 'stl_vacuum_detail'),
#  ('pg_catalog', 'stl_vacuum_history'),
#  ('pg_catalog', 'stl_vacuum_scan_query_usage'),
#  ('pg_catalog', 'stl_varbyte_column_linker'),
#  ('pg_catalog', 'stl_varbyte_function'),
#  ('pg_catalog', 'stl_varbyte_query'),
#  ('pg_catalog', 'stl_vec_scan_stats'),
#  ('pg_catalog', 'stl_version'),
#  ('pg_catalog', 'stl_volt_tt_sizes'),
#  ('pg_catalog', 'stl_vpid'),
#  ('pg_catalog', 'stl_vpid_error'),
#  ('pg_catalog', 'stl_wam_lifecycle'),
#  ('pg_catalog', 'stl_warning'),
#  ('pg_catalog', 'stl_window'),
#  ('pg_catalog', 'stl_wlm_auto_concurrency'),
#  ('pg_catalog', 'stl_wlm_error'),
#  ('pg_catalog', 'stl_wlm_query'),
#  ('pg_catalog', 'stl_wlm_query_preemption'),
#  ('pg_catalog', 'stl_wlm_rule_action'),
#  ('pg_catalog', 'stl_wlm_service_class_config'),
#  ('pg_catalog', 'stl_wlm_trace'),
#  ('pg_catalog', 'stl_wlm_trace_query_state'),
#  ('pg_catalog', 'stl_xid_consumption_rate'),
#  ('pg_catalog', 'stl_xregion_billing_error'),
#  ('pg_catalog', 'stl_xregion_metering'),
#  ('pg_catalog', 'stl_xrestore'),
#  ('pg_catalog', 'stl_xrestore_alter_distkey'),
#  ('pg_catalog', 'stl_xrestore_cluster_level_distkey_tables'),
#  ('pg_catalog', 'stll_abort_idle'),
#  ('pg_catalog', 'stll_aggr'),
#  ('pg_catalog', 'stll_aggr_distinct'),
#  ('pg_catalog', 'stll_alert_event_log'),
#  ('pg_catalog', 'stll_alert_messages'),
#  ('pg_catalog', 'stll_alter_column_encode_events'),
#  ('pg_catalog', 'stll_alter_column_events'),
#  ('pg_catalog', 'stll_alter_dist_sort'),
#  ('pg_catalog', 'stll_alter_sortkey_events'),
#  ('pg_catalog', 'stll_analyze'),
#  ('pg_catalog', 'stll_analyze_compression'),
#  ('pg_catalog', 'stll_aqua_pushdown'),
#  ('pg_catalog', 'stll_aqua_requests'),
#  ('pg_catalog', 'stll_arcadia_billing_log'),
#  ('pg_catalog', 'stll_arcadia_billing_ris_reports'),
#  ('pg_catalog', 'stll_arcadia_billing_xact_log'),
#  ('pg_catalog', 'stll_arcadia_concurrency_scaling_usage'),
#  ('pg_catalog', 'stll_arcadia_concurrency_scaling_usage_error'),
#  ('pg_catalog', 'stll_arcadia_main_usage'),
#  ('pg_catalog', 'stll_arcadia_main_usage_error'),
#  ('pg_catalog', 'stll_auto_alter_worker_event'),
#  ('pg_catalog', 'stll_auto_dispatcher_wlm_occupancy'),
#  ('pg_catalog', 'stll_auto_maintenance'),
#  ('pg_catalog', 'stll_auto_maintenance_worker'),
#  ('pg_catalog', 'stll_auto_task_events'),
#  ('pg_catalog', 'stll_auto_worker_levels'),
#  ('pg_catalog', 'stll_autovacuum_detail'),
#  ('pg_catalog', 'stll_autovacuum_skip_reason'),
#  ('pg_catalog', 'stll_awsclient_error'),
#  ('pg_catalog', 'stll_background_monitor'),
#  ...]

# %% [markdown]
# ## STEP 5: Clean up your resources

# %% [markdown]
# <b><font color='red'>DO NOT RUN THIS UNLESS YOU ARE SURE <br/>
#     We will be using these resources in the next exercises</span></b>

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!
# Out:
# {'Cluster': {'ClusterIdentifier': 'dwhcluster',
#   'NodeType': 'dc2.large',
#   'ClusterStatus': 'deleting',
#   'ClusterAvailabilityStatus': 'Modifying',
#   'MasterUsername': 'admindwh',
#   'DBName': 'public',
#   'Endpoint': {'Address': 'dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com',
#    'Port': 5439},
#   'ClusterCreateTime': datetime.datetime(2022, 9, 9, 6, 23, 51, 710000, tzinfo=tzutc()),
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'ManualSnapshotRetentionPeriod': -1,
#   'ClusterSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-08e2f1e0a2c5adbd5',
#     'Status': 'active'}],
#   'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#     'ParameterApplyStatus': 'in-sync'}],
#   'ClusterSubnetGroupName': 'default',
#   'VpcId': 'vpc-0a41629468dbdb865',
#   'AvailabilityZone': 'us-west-2d',
#   'PreferredMaintenanceWindow': 'mon:10:30-mon:11:00',
#   'PendingModifiedValues': {},
#   'ClusterVersion': '1.0',
#   'AllowVersionUpgrade': True,
#   'NumberOfNodes': 4,
#   'PubliclyAccessible': True,
#   'Encrypted': False,
#   'Tags': [],
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'IamRoleArn': 'arn:aws:iam::167023846835:role/dwhRole',
#     'ApplyStatus': 'in-sync'}],
#   'MaintenanceTrackName': 'current',
#   'DeferredMaintenanceWindows': [],
#   'NextMaintenanceWindowStartTime': datetime.datetime(2022, 9, 12, 10, 30, tzinfo=tzutc()),
#   'TotalStorageCapacityInMegaBytes': 1600000,
#   'AquaConfiguration': {'AquaStatus': 'disabled',
#    'AquaConfigurationStatus': 'auto'}},
#  'ResponseMetadata': {'RequestId': '124ab790-5e60-407c-9fca-bf777dad31fa',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '124ab790-5e60-407c-9fca-bf777dad31fa',
#    'content-type': 'text/xml',
#    'content-length': '2707',
#    'vary': 'accept-encoding',
#    'date': 'Fri, 09 Sep 2022 07:54:51 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# - run this block several times until the cluster really deleted

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  deleting
# 3  admindwh
# 4  public
# 5  {'Address': 'dwhcluster.ckesytmadupu.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0a41629468dbdb865
# 7  4

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
# Out:
# {'ResponseMetadata': {'RequestId': '0e689d40-101f-4f3f-82c3-6a0bfb36ef17',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '0e689d40-101f-4f3f-82c3-6a0bfb36ef17',
#    'content-type': 'text/xml',
#    'content-length': '200',
#    'date': 'Fri, 09 Sep 2022 07:54:55 GMT'},
#   'RetryAttempts': 0}}
